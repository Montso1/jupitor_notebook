# %%
import pandas as pd

# %%
student_results = pd.read_csv("student_performance_dataset.csv")
print(student_results.head())
# Out:
#      Student_Name  Study_Hours  Attendance_Pct  Class_Participation  \
# 0      Liam Smith           15              95                    8
# 1  Olivia Johnson            5              70                    4
# 2   Noah Williams           12              88                    7
# 3      Emma Brown           18              98                    9
# 4    Oliver Jones            7              80                    5
#
#    Previous_Score  Final_Score
# 0              85           90
# 1              60           55
# 2              78           82
# 3              92           96
# 4              65           68

# %%
selected_students_results = df [["Student_Name", "Study_Hours"]]

# %%
print(selected_students_results)
# Out:
#          Student_Name  Study_Hours
# 0          Liam Smith           15
# 1      Olivia Johnson            5
# 2       Noah Williams           12
# 3          Emma Brown           18
# 4        Oliver Jones            7
# 5          Ava Garcia            3
# 6       Elijah Miller           14
# 7     Charlotte Davis           20
# 8   William Rodriguez            9
# 9     Sophia Martinez           11
# 10    James Hernandez           16
# 11       Amelia Lopez            6
# 12  Benjamin Gonzalez           13
# 13    Isabella Wilson           19
# 14     Lucas Anderson            8
# 15         Mia Thomas            4
# 16       Henry Taylor           15
# 17       Evelyn Moore           21
# 18  Alexander Jackson           10
# 19      Harper Martin           12
# 20          Mason Lee           14
# 21       Camila Perez            5
# 22   Michael Thompson           11
# 23       Gianna White           17
# 24       Ethan Harris            8
# 25    Abigail Sanchez            2
# ...

# %%
first_two_rows = selected_students_results.head(2)

# %%
print (first_two_rows)
# Out:
#      Student_Name  Study_Hours
# 0      Liam Smith           15
# 1  Olivia Johnson            5
